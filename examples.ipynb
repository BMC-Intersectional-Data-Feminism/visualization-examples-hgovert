# %%
import pandas as pd ## for tables
import numpy as np ## for arrays
import matplotlib.pyplot as plt ## for figures
import seaborn as sns ## for prettier figures

# %%
df = pd.read_csv('spotify.csv') # read in spotify data
df
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 0    2017-01-06      12287078        NaN                       NaN        NaN
# 1    2017-01-07      13190270        NaN                       NaN        NaN
# 2    2017-01-08      13099919        NaN                       NaN        NaN
# 3    2017-01-09      14506351        NaN                       NaN        NaN
# 4    2017-01-10      14275628        NaN                       NaN        NaN
# ..          ...           ...        ...                       ...        ...
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 361      2869783.0
# 362      2743748.0
# 363      2441045.0
# 364      2622693.0
# 365      2627334.0
#
# [366 rows x 6 columns]

# %%
fig, ax = plt.subplots()

ax.plot(df['Date'], df['Shape of You'])

#xticks = list(df['Date'])[]

#ax.tick_params(df['Shape of You'], rotation=45)

#ax.set_xticks(df['Date'], rotation = 'vertical')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       2 ax.plot(df['Date'], df['Shape of You'])
#       3 #ax.tick_params(df['Shape of You'], rotation=45)
# ----> 4 ax.set_xticks(df['Date'], rotations = 'vertical')
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/axis.py:2214, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    2212 if labels is None and kwargs:
#    2213     first_key = next(iter(kwargs))
# -> 2214     raise ValueError(
#    2215         f"Incorrect use of keyword argument {first_key!r}. Keyword arguments "
#    2216         "other than 'minor' modify the text labels and can only be used if "
#    2217         "'labels' are passed as well.")
#    2218 result = self._set_tick_locations(ticks, minor=minor)
#    2219 if labels is not None:
#
# ValueError: Incorrect use of keyword argument 'rotations'. Keyword arguments other than 'minor' modify the text labels and can only be used if 'labels' are passed as well.

# %%
plt.plot(df['Date'], df['Shape of You'], label = 'Shape of You')
plt.plot(df['Date'], df['Despacito'], label = 'Despacito')
plt.legend()
plt.xlabel('Dates')
plt.ylabel('Streams')
# Out:
# Text(0, 0.5, 'Streams')

# %%
plt.scatter(df['Date'], df['Shape of You'], label = 'Shape of You')
plt.scatter(df['Date'], df['Despacito'], label = 'Despacito')
plt.legend()
plt.xlabel('Dates')
plt.ylabel('Streams')
# Out:
# Text(0, 0.5, 'Streams')
